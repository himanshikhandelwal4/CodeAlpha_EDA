# %%
import pandas as pd

df = pd.read_csv("Amazon_Sales.csv")

df.head()
# Out:
#    Order ID     Product     Category  Amount  Quantity Order Date     Status  \
# 0      1001   Earphones  Electronics     799         1   1/5/2023  Delivered
# 1      1002  Smartwatch  Electronics    2499         1   1/7/2023  Cancelled
# 2      1003  Phone Case  Accessories     299         2   1/9/2023  Delivered
# 3      1004  Laptop Bag  Accessories    1099         1  1/11/2023    Shipped
# 4      1005  Power Bank  Electronics    1499         1  1/12/2023  Delivered
#
#   Customer
# 0     Amit
# 1     Riya
# 2    Karan
# 3    Sneha
# 4    Vikas

# %%
df.shape
# Out:
# (5, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order ID    5 non-null      int64
#  1   Product     5 non-null      object
#  2   Category    5 non-null      object
#  3   Amount      5 non-null      int64
#  4   Quantity    5 non-null      int64
#  5   Order Date  5 non-null      object
#  6   Status      5 non-null      object
#  7   Customer    5 non-null      object
# dtypes: int64(3), object(5)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#           Order ID       Amount  Quantity
# count     5.000000     5.000000  5.000000
# mean   1003.000000  1239.000000  1.200000
# std       1.581139   829.457654  0.447214
# min    1001.000000   299.000000  1.000000
# 25%    1002.000000   799.000000  1.000000
# 50%    1003.000000  1099.000000  1.000000
# 75%    1004.000000  1499.000000  1.000000
# max    1005.000000  2499.000000  2.000000

# %%
df.isnull().sum()
# Out:
# Order ID      0
# Product       0
# Category      0
# Amount        0
# Quantity      0
# Order Date    0
# Status        0
# Customer      0
# dtype: int64

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Category", data=df)
plt.title("Sales Count by Category")
plt.show()

# %%
df['Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Order Status Distribution")
plt.show()

# %%
sns.histplot(df["Amount"])
plt.title("Amount Distribution")
plt.show()
